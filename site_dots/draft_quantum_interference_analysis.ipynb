# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import functions_spin_p as fy
from importlib import reload

reload(fy)
# Out:
# <module 'functions_spin_p' from '/mnt/c/Users/frnkl/Desktop/thesis_spin_caloritronics/tesis_models/site_dots/functions_spin_p.py'>

# %%
#Energy axis

energy_axis = np.arange(-8, 8 + 0.01, 0.01) #meV
print("Energy axis is", energy_axis,"meV")

#Gamma i.e. width parameter
gamma = 0.5 #meV
print("The width is:",gamma,"meV")

#Site energies:
e_01 = 0 #meV
e_02 = 0 #meV
e_11 = 1 #meV
e_12 = 1 #meV

# Interdot Hopping
v = 4*gamma
# Out:
# Energy axis is [-8.   -7.99 -7.98 ...  7.98  7.99  8.  ] meV
# The width is: 0.5 meV

# %%
# do not forget constrained_layout=True to have some space between axes
fig = plt.figure(constrained_layout=True, figsize=(18,11), dpi=300)

#Set the grid for the subplots
gs = GridSpec(1, 1, figure=fig)

#Add the subplots
ax1 = fig.add_subplot(gs[0, 0])

#POLARIZATION = 0
# Transmission spin up Plot
p=0

ax1.grid(linestyle=':', color='grey')
################################################################################################################
#Definition of the Hamiltonian 

#Innerdot Hopping parameter:
om = 0*gamma #meV

#Renormalized site energies array:
e_ren_1_u = np.array([e_01,e_11, om])
e_ren_1_d = np.array([e_01,e_11, om])

e_ren_2_u = np.array([e_02, e_12, om])
e_ren_2_d = np.array([e_02, e_12, om])


site_energies = np.array([e_ren_1_u, e_ren_1_d , e_ren_2_u , e_ren_2_d], dtype = complex)
#print(site_energies)

Hamiltonian = np.array([[0,0,v,0],[0,0,0,v],[v,0,0,0],[0,v,0,0]], dtype = complex)

ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "b", label=r"$\omega\,=\,$"+str(om/gamma)+r"$\gamma$", linestyle="-.", lw=4)

##################################################################################################################
#Definition of the Hamiltonian 

#Innerdot Hopping parameter:
om = 1*gamma #meV

#Renormalized site energies array:
e_ren_1_u = np.array([e_01,e_11, om])
e_ren_1_d = np.array([e_01,e_11, om])

e_ren_2_u = np.array([e_02, e_12, om])
e_ren_2_d = np.array([e_02, e_12, om])


site_energies = np.array([e_ren_1_u, e_ren_1_d , e_ren_2_u , e_ren_2_d], dtype = complex)
#print(site_energies)

Hamiltonian = np.array([[0,0,v,0],[0,0,0,v],[v,0,0,0],[0,v,0,0]], dtype = complex)

ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "m", label=r"$\omega\,=\,$"+str(om/gamma)+r"$\gamma$", linestyle="-", lw=4)

#####################################################################################################################
#Definition of the Hamiltonian 

#Innerdot Hopping parameter:
om = 8*gamma #meV

#Renormalized site energies array:
e_ren_1_u = np.array([e_01,e_11, om])
e_ren_1_d = np.array([e_01,e_11, om])

e_ren_2_u = np.array([e_02, e_12, om])
e_ren_2_d = np.array([e_02, e_12, om])


site_energies = np.array([e_ren_1_u, e_ren_1_d , e_ren_2_u , e_ren_2_d], dtype = complex)
#print(site_energies)

Hamiltonian = np.array([[0,0,v,0],[0,0,0,v],[v,0,0,0],[0,v,0,0]], dtype = complex)

ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "r", label=r"$\omega\,=\,$"+str(om/gamma)+r"$\gamma$", linestyle="--", lw=4)

############################################################################################################################
ax1.set_xlabel(r'$E\,[meV]$',fontsize=30)
ax1.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=30)
ax1.legend(
    fontsize=25,
    title="Hopping "+r"$\omega$",
    title_fontsize=25,
    loc="upper right"
)

# Stablish limits for the subplots
ax1.set_ylim(0, 2.5)  
ax1.set_xlim(-7, 7)  

# Set the fontsize for the x and y ticks
ax1.tick_params(axis='x', labelsize=30)
ax1.tick_params(axis='y', labelsize=30)

# Ajustar el diseño y mostrar los subplots
plt.suptitle("Transmission vs Energy "+r" ($p_{L}=p_{R}=$"+str(p)+r" & $V=$"+str(v/gamma)+r"$\gamma$)", fontsize=30)
plt.tight_layout()
plt.show()
#fig.savefig('site_dots_Transmission_reference.jpg')
# Out:
# /home/franklin/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:101: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
#Definition of the Hamiltonian 
# Interdot Hopping
v = -7*gamma

#Intradot Hopping parameter:
#om = 0.4*gamma #meV
om = 0*gamma #meV

#Spin degeneration
delta= 1 #meV

#Renormalized site energies array:
e_ren_1_u = np.array([e_01+delta,e_11+delta, om])
e_ren_1_d = np.array([e_01-delta,e_11-delta, om])

e_ren_2_u = np.array([e_02+delta, e_12+delta, om])
e_ren_2_d = np.array([e_02-delta, e_12-delta, om])


site_energies = np.array([e_ren_1_u, e_ren_1_d , e_ren_2_u , e_ren_2_d], dtype = complex)
#print(site_energies)

Hamiltonian = np.array([[0,0,v,0],[0,0,0,v],[v,0,0,0],[0,v,0,0]], dtype = complex)

# %%
# do not forget constrained_layout=True to have some space between axes
fig = plt.figure(constrained_layout=True, figsize=(26,8), dpi=300)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0)

#Set the grid for the subplots
gs = GridSpec(1, 3, figure=fig)

#Add the subplots
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])

#POLARIZATION = 0
# Transmission spin up Plot
p=0

ax1.grid(linestyle=':', color='grey')
ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "m", lw=4)
ax1.set_xlabel(r'$E\,[meV]$',fontsize=30)
ax1.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=30)
ax1.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p), transform=ax1.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)
ax1.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p), transform=ax1.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)

p= 0.5

ax2.grid(linestyle=':', color='grey')
ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "m", lw=4)
ax2.set_xlabel(r'$E\,[meV]$',fontsize=30)
#ax2.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=30)
ax2.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p), transform=ax2.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)
ax2.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p), transform=ax2.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)

k=0.5
p_L = k
p_R = -k

ax3.grid(linestyle=':', color='grey')
ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1], "m", lw=4)
ax3.set_xlabel(r'$E\,[meV]$',fontsize=30)
#ax3.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=30)
ax3.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p_L), transform=ax3.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)
ax3.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p_R), transform=ax3.transAxes, fontsize=30,
        verticalalignment='top', bbox=props)



# Stablish limits for the subplots
ax1.set_ylim(0, 2.5)  
ax2.set_ylim(0, 2.5)   
ax3.set_ylim(0, 2.5) 
ax1.set_xlim(-8, 8)  
ax2.set_xlim(-8, 8)   
ax3.set_xlim(-8, 8) 

# Set the fontsize for the x and y ticks
ax1.tick_params(axis='x', labelsize=30)
ax1.tick_params(axis='y', labelsize=30)
ax2.tick_params(axis='x', labelsize=30)
ax2.tick_params(axis='y', labelsize=30)
ax3.tick_params(axis='x', labelsize=30)
ax3.tick_params(axis='y', labelsize=30)

# Eliminar los números del eje x en el primer subplot
ax2.set_yticklabels([])
ax3.set_yticklabels([])

# Ajustar el diseño y mostrar los subplots
plt.suptitle("Transmission vs Energy "+r" ($V=$"+str(v/gamma)+r"$\gamma$ & $\omega=$"+str(om/gamma)+r"$\gamma$)", fontsize=30)
plt.tight_layout()
plt.show()
#fig.savefig('site_dots_Transmission_polarization.jpg')
# Out:
# /home/franklin/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:79: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
# do not forget constrained_layout=True to have some space between axes
fig = plt.figure(constrained_layout=True, figsize=(26,8), dpi=300)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0)

#Set the grid for the subplots
gs = GridSpec(1, 3, figure=fig)

#Add the subplots
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])

#POLARIZATION = 0
# Transmission spin up Plot
p=0

ax1.grid(linestyle=':', color='grey')
ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#1f77b4", lw=5, label=r"$T=T_{\uparrow}+T_{\downarrow}$")
ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0], "#ff7f0e", lw=4, linestyle="--", label=r"$T_{\uparrow}$")
ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#2ca02c", lw=4, linestyle="-.", label=r"$T_{\downarrow}$")
ax1.set_xlabel(r'$E\,[meV]$',fontsize=30)
ax1.set_ylabel(r'$T(E)$',fontsize=30)
# ax1.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p), transform=ax1.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# ax1.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p), transform=ax1.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# Etiqueta a)
ax1.text(-0.05, 1.05, r'a)'+r"$p_{L}\,=\,$"+str(p)+r", $p_{R}\,=\,$"+str(p), transform=ax1.transAxes, fontsize=30, fontweight='bold')
ax1.legend(
    fontsize=20,
    title="Transmission component:",
    title_fontsize=20
)

# t1=fy.Transmission(energy_axis, gamma, Hamiltonian, p, p)[0]\
#      +fy.Transmission(energy_axis, gamma, Hamiltonian, p, p)[1]

p= 0.5
ax2.grid(linestyle=':', color='grey')
#ax2.plot(energy_axis, t1, "b", lw=4)
ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#1f77b4", lw=5, label=r"$T=T_{\uparrow}+T_{\downarrow}$")
ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0], "#ff7f0e", lw=4, linestyle="--", label=r"$T_{\uparrow}$")
ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#2ca02c", lw=4, linestyle="-.", label=r"$T_{\downarrow}$")
ax2.set_xlabel(r'$E\,[meV]$',fontsize=30)
#ax2.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=18)
# ax2.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p), transform=ax2.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# ax2.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p), transform=ax2.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# Etiqueta b)
ax2.text(-0.05, 1.05, r'b)'+r"$p_{L}\,=\,$"+str(p)+r", $p_{R}\,=\,$"+str(p), transform=ax2.transAxes, fontsize=30, fontweight='bold')
ax2.legend(
    fontsize=20,
    title="Transmission component:",
    title_fontsize=20
)

k=0.5
p_L= k
p_R = -k

ax3.grid(linestyle=':', color='grey')
ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1], "#1f77b4", lw=5, label=r"$T=T_{\uparrow}+T_{\downarrow}$")
ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0], "#ff7f0e", lw=4, linestyle="--", label=r"$T_{\uparrow}$")
ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1], "#2ca02c", lw=4, linestyle="-.", label=r"$T_{\downarrow}$")
ax3.set_xlabel(r'$E\,[meV]$',fontsize=30)
#ax3.set_ylabel(r'$T(E) = T_{\uparrow}(E)+T_{\downarrow}(E)$',fontsize=18)
# ax3.text(0.05, 0.95, r"$p_{L}\,=\,$"+str(p_L), transform=ax3.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# ax3.text(0.05, 0.85, r"$p_{R}\,=\,$"+str(p_R), transform=ax3.transAxes, fontsize=30,
#         verticalalignment='top', bbox=props)
# Etiqueta c)
ax3.text(-0.05, 1.05, r'c)'+r"$p_{L}\,=\,$"+str(p_L)+r", $p_{R}\,=\,$"+str(p_R), transform=ax3.transAxes, fontsize=30, fontweight='bold')
ax3.legend(
    fontsize=20,
    title="Transmission component:",
    title_fontsize=20
)


# Stablish limits for the subplots
ax1.set_ylim(0, 2.5)  
ax2.set_ylim(0, 2.5)   
ax3.set_ylim(0, 2.5) 
ax1.set_xlim(-8, 8)  
ax2.set_xlim(-8, 8)   
ax3.set_xlim(-8, 8) 

# Set the fontsize for the x and y ticks
ax1.tick_params(axis='x', labelsize=30)
ax1.tick_params(axis='y', labelsize=30)
ax2.tick_params(axis='x', labelsize=30)
ax2.tick_params(axis='y', labelsize=30)
ax3.tick_params(axis='x', labelsize=30)
ax3.tick_params(axis='y', labelsize=30)

# Eliminar los números del eje x en el primer subplot
ax2.set_yticklabels([])
ax3.set_yticklabels([])

# Ajustar el diseño y mostrar los subplots
plt.suptitle("Transmission vs Energy "+r" ($V=$"+str(v/gamma)+r"$\gamma$ & $\omega=$"+str(om/gamma)+r"$\gamma$)", fontsize=30)
plt.tight_layout()
plt.show()
#fig.savefig('site_dots_Transmission_polarization_v2.jpg')
# Out:
# /home/franklin/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:108: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
# do not forget constrained_layout=True to have some space between axes
fig = plt.figure(constrained_layout=True, figsize=(26,8), dpi=300)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0)

#Set the grid for the subplots
gs = GridSpec(1, 3, figure=fig)

#Add the subplots
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])

#POLARIZATION = 0
# Transmission spin up Plot
# p=0

# ax1.grid(linestyle=':', color='grey')
# ax2.grid(linestyle=':', color='grey')
# ax3.grid(linestyle=':', color='grey')
# ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0]\
#      +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#1f77b4", lw=5, label=r"$T=T_{\uparrow}+T_{\downarrow}$")
# ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[0], "#ff7f0e", lw=4, linestyle="-", label=r"$T_{\uparrow}$")
# ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p, p)[1], "#2ca02c", lw=4, linestyle="-", label=r"$T_{\downarrow}$")
# ax1.set_xlabel(r'$E\,[meV]$',fontsize=30)
# ax1.set_ylabel(r'$T(E)$',fontsize=30)

##################################################################

k=1
p_L= k
p_R = 0

ax1.grid(linestyle=':', color='grey')
ax2.grid(linestyle=':', color='grey')
ax3.grid(linestyle=':', color='grey')
ax3.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0]\
     +fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1], "#1f77b4", lw=5, label=r"$T=T_{\uparrow}+T_{\downarrow}$")
ax1.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0], "#ff7f0e", lw=4, linestyle="--", label=r"$T_{\uparrow}$")
ax2.plot(energy_axis, fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1], "#2ca02c", lw=4, linestyle="-.", label=r"$T_{\downarrow}$")
ax3.set_xlabel(r'$E\,[meV]$',fontsize=30)


# Stablish limits for the subplots
ax1.set_ylim(0, 2.5)  
ax2.set_ylim(0, 2.5)   
ax3.set_ylim(0, 2.5) 
ax1.set_xlim(-8, 8)  
ax2.set_xlim(-8, 8)   
ax3.set_xlim(-8, 8) 

# Set the fontsize for the x and y ticks
ax1.tick_params(axis='x', labelsize=30)
ax1.tick_params(axis='y', labelsize=30)
ax2.tick_params(axis='x', labelsize=30)
ax2.tick_params(axis='y', labelsize=30)
ax3.tick_params(axis='x', labelsize=30)
ax3.tick_params(axis='y', labelsize=30)

# Eliminar los números del eje x en el primer subplot
ax2.set_yticklabels([])
ax3.set_yticklabels([])

# Ajustar el diseño y mostrar los subplots
plt.suptitle("Transmission vs Energy "+r" ($V=$"+str(v/gamma)+r"$\gamma$ & $\omega=$"+str(om/gamma)+r"$\gamma$)", fontsize=30)
plt.tight_layout()
plt.show()
#fig.savefig('site_dots_Transmission_polarization_v2.jpg')
# Out:
# /home/franklin/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.

# %%
#POLARIZATION p_L = p_R = 0
p_L = 1
p_R = 0

#Transmission axis

transmission_u_L_1 = fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[0]
transmission_d_L_1 = fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L, p_R)[1]

# %%
#POLARIZATION UP-UP
p_L_1 = -1
p_R_1 = 0

#Transmission axis

transmission_u_1_L_1 = fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L_1, p_R_1)[0]
transmission_d_1_L_1 = fy.Transmission(energy_axis, gamma, Hamiltonian, site_energies, p_L_1, p_R_1)[1]

# %%
T_UP_L_1 = transmission_u_L_1 + transmission_d_L_1
T_DOWN_L_1 = transmission_u_1_L_1 + transmission_d_1_L_1

SP1_L_1 = -( (T_UP_L_1-T_DOWN_L_1)/(T_UP_L_1+T_DOWN_L_1) )*100

# %%
# Crear la figura y los ejes
fig, ax1 = plt.subplots(figsize=(14, 7), dpi=300)

# Define the first axis and its y-scale (linear scale)
ax1.plot(energy_axis, SP1_L_1, color="#DC143C", label=r"$SP$", lw=4)
ax1.set_xlabel(r"$E\,[meV]$", fontsize=30)
ax1.set_ylabel(r"$SP\,[\%]$", fontsize=30)

# Make the second y axis (logarítmic scale)
ax2 = ax1.twinx()
# ax2.plot(energy_axis, transmission_u_L_1 + transmission_d_L_1, "#000000", linestyle="-.", label=r"$T_{UP}$", lw=2)
# ax2.plot(energy_axis, transmission_u_1_L_1 + transmission_d_1_L_1, "#1f77b4", linestyle="-.", label=r"$T_{DOWN}$", lw=2)
ax2.plot(energy_axis, transmission_u_L_1 + transmission_d_L_1,  "#1f77b4", linestyle="-.", label=r"$T_{UP}$", lw=2)
ax2.plot(energy_axis, transmission_u_1_L_1 + transmission_d_1_L_1, "#000000", linestyle="-.", label=r"$T_{DOWN}$", lw=2)

ax2.set_ylabel(r"$Transmission_{total}$", fontsize=30)

# Obtain legends and lines for both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

# Locate the legends such that it is not superposed
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right', fontsize=20)

# Adjust the x axis ticks
ax1.set_xlim(-6, 6)

# Establish the x axis ticks in intervals of 1
ax1.set_xticks(range(-5, 4 + 2, 1))

# Set the fontsize for the x and y ticks
ax1.tick_params(axis='x', labelsize=30)
ax1.tick_params(axis='y', labelsize=30)
ax2.tick_params(axis='y', labelsize=30)

# Headline
#plt.suptitle("Spin Polarization " + r"($t=$" + str(t/gamma) + r"$\gamma$, " + r"$\omega=$" + str(om/gamma) + r"$\gamma\,\,&\,B=$" + str(B) + r"$\lambda_{2}\,meV$)", fontsize=30, y=0.95)

# Show the image
plt.show()

# Save the image
fig.savefig('spin_polarization_site_dots.jpg', bbox_inches='tight')
